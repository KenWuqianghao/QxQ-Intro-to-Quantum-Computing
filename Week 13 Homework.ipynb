# %%
import numpy as np
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, execute, transpile, Aer, IBMQ
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *

# Loading your IBM Quantum account(s)
provider = IBMQ.save_account('4dc9a48a37597e50a5e221436c94436125aa41acfe1ec9ce2e019427d84d882f5612390df5e8e679c47952040701380b9786ee099187009709a78bfd06dab925')
print('Libraries imported successfully!')
# Out:
# configrc.store_credentials:WARNING:2022-01-23 15:41:04,688: Credentials already present. Set overwrite=True to overwrite.
# Libraries imported successfully!

# %%
qc = QuantumCircuit(2)
qc.x(0)
qc.x(1)
backend = Aer.get_backend('statevector_simulator')
job = execute(qc,backend)
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %%
qc = QuantumCircuit(2)
qc.h(0)
backend = Aer.get_backend('statevector_simulator')
job = execute(qc,backend)
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %%
qc = QuantumCircuit(2)
bit = 0
if bit == 1:
    qc.x(0)
qc.cx(0,1)
qc.draw()
# Out:
#
# q_0: ──■──
#      ┌─┴─┐
# q_1: ┤ X ├
#      └───┘
